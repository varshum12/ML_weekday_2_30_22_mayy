# %% [markdown]
# ## Data import / collection

# %%
path  =  r"C:\Users\C S\Downloads\Cars93.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=  pd.read_csv(path , keep_default_na= False  , na_values= ['NA'  , ""])

# %% [markdown]
# ## Basic Checks

# %%
df.head()
# Out:
#    id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 0   1        Acura  Integra    Small       12.9   15.9       18.8        25
# 1   2        Acura   Legend  Midsize       29.2   33.9       38.7        18
# 2   3         Audi       90  Compact       25.9   29.1       32.3        20
# 3   4         Audi      100  Midsize       30.8   37.7       44.6        19
# 4   5          BMW     535i  Midsize       23.7   30.0       36.2        22
#
#    MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 0           31                None  ...          5    177        102     68
# 1           25  Driver & Passenger  ...          5    195        115     71
# 2           26         Driver only  ...          5    180        102     67
# 3           26                 NaN  ...          6    193        106     70
# 4           30         Driver only  ...          4    186        109     69
#
# ...

# %%
df.tail()
# Out:
#     id Manufacturer    Model     Type  Min.Price  Price  Max.Price  MPG.city  \
# 88  89   Volkswagen  Eurovan      Van       16.6   19.7       22.7        17
# 89  90   Volkswagen   Passat  Compact       17.6   20.0       22.4        21
# 90  91   Volkswagen  Corrado   Sporty       22.9   23.3       23.7        18
# 91  92        Volvo      240  Compact       21.8   22.7       23.5        21
# 92  93        Volvo      850  Midsize       24.8   26.7       28.5        20
#
#     MPG.highway             AirBags  ... Passengers Length  Wheelbase  Width  \
# 88           21                None  ...          7    187        115     72
# 89           30                None  ...          5    180        103     67
# 90           25                None  ...          4    159         97     66
# 91           28         Driver only  ...          5    190        104     67
# 92           28  Driver & Passenger  ...          5    184        105     69
#
# ...

# %%
df.columns
# Out:
# Index(['id', 'Manufacturer', 'Model', 'Type', 'Min.Price', 'Price',
#        'Max.Price', 'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain',
#        'Cylinders', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile',
#        'Man.trans.avail', 'Fuel.tank.capacity', 'Passengers', 'Length',
#        'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room',
#        'Weight', 'Origin', 'Make'],
#       dtype='object')

# %%
# drop id column
df.drop(['id'], axis =  1, inplace  = True)

# %%
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Type                   0
# Min.Price              0
# Price                  0
# Max.Price              0
# MPG.city               0
# MPG.highway            0
# AirBags                4
# DriveTrain             0
# Cylinders              0
# EngineSize             0
# Horsepower             0
# RPM                    0
# Rev.per.mile           0
# Man.trans.avail        0
# Fuel.tank.capacity     0
# Passengers             0
# Length                 0
# Wheelbase              0
# Width                  0
# Turn.circle            0
# Rear.seat.room         2
# Luggage.room          11
# Weight                 0
# Origin                 0
# Make                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# seperate x and y 
x  =  df.drop(['Price'] , axis =  1)
y =  df['Price']

# %%
# Use pipeline for preprocessing
from sklearn.preprocessing import OrdinalEncoder  , StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OrdinalEncoder , StandardScaler
from sklearn.impute import SimpleImputer

# %%
cat  =  []
num  = []
for i in x.columns:
    if x[i].dtype == 'object':
        cat.append(i)
    else:
        num.append(i)

# %%
# Seperate numerical  data  
num  =[]
cat  = []
for i in x.columns:
    if x[i].dtype!='object':
        num.append(i)
    else:
        cat.append(i)

# %%
print(cat)

print()

print(num)
# Out:
# ['Manufacturer', 'Model', 'Type', 'AirBags', 'DriveTrain', 'Cylinders', 'Man.trans.avail', 'Origin', 'Make']
#
# ['Min.Price', 'Max.Price', 'MPG.city', 'MPG.highway', 'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width', 'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight']

# %%
# create num and cat pipeline
num_pipeline  =  Pipeline(steps =  [('imputer'  , SimpleImputer(strategy= 'mean' )),
                                          ('scaler' ,StandardScaler()) ] )

cat_pipeline  =  Pipeline(steps  =  [('encoder' , OrdinalEncoder()) ,
                                    ('imputer'  , SimpleImputer(strategy= 'most_frequent'))])

# %%
# connect pipeline
pre  = ColumnTransformer([('num_pipeline' , num_pipeline , num)  , 
                         ('cat_pipeline' , cat_pipeline , cat )])

# %%
pre
# Out:
# ColumnTransformer(transformers=[('num_pipeline',
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['Min.Price', 'Max.Price', 'MPG.city',
#                                   'MPG.highway', 'EngineSize', 'Horsepower',
#                                   'RPM', 'Rev.per.mile', 'Fuel.tank.capacity',
#                                   'Passengers', 'Length', 'Wheelbase', 'Width',
#                                   'Turn.circle', 'Rear.seat.room',
#                                   'Luggage.room', 'Weight']),
#                                 ('cat_pipeline',
#                                  Pipeline(steps=[('encoder', OrdinalEncoder()),
#                                                  ('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
# ...

# %%
# Apply to x variables

# %%
x
# Out:
#    Manufacturer    Model     Type  Min.Price  Max.Price  MPG.city  \
# 0         Acura  Integra    Small       12.9       18.8        25
# 1         Acura   Legend  Midsize       29.2       38.7        18
# 2          Audi       90  Compact       25.9       32.3        20
# 3          Audi      100  Midsize       30.8       44.6        19
# 4           BMW     535i  Midsize       23.7       36.2        22
# ..          ...      ...      ...        ...        ...       ...
# 88   Volkswagen  Eurovan      Van       16.6       22.7        17
# 89   Volkswagen   Passat  Compact       17.6       22.4        21
# 90   Volkswagen  Corrado   Sporty       22.9       23.7        18
# 91        Volvo      240  Compact       21.8       23.5        21
# 92        Volvo      850  Midsize       24.8       28.5        20
#
#     MPG.highway             AirBags DriveTrain Cylinders  ...  Passengers  \
# 0            31                None      Front         4  ...           5
# ...

# %%
x1 = pre.fit_transform(x)

# %%
x1
# Out:
# array([[-0.48578741, -0.28246529,  0.47131249, ...,  1.        ,
#          1.        ,  0.        ],
#        [ 1.38801699,  1.53140881, -0.78103212, ...,  1.        ,
#          1.        ,  1.        ],
#        [ 1.00865782,  0.94805231, -0.42321938, ...,  1.        ,
#          1.        ,  3.        ],
#        ...,
#        [ 0.66378585,  0.16416702, -0.78103212, ...,  1.        ,
#          1.        , 87.        ],
#        [ 0.53733279,  0.14593713, -0.244313  , ...,  1.        ,
#          1.        , 91.        ],
#        [ 0.88220476,  0.60168439, -0.42321938, ...,  1.        ,
#          1.        , 92.        ]], shape=(93, 26))

# %%
# convert in dataframe

x1  =  pd.DataFrame(x1 , columns = pre.get_feature_names_out())

# %%
x1
# Out:
#     num_pipeline__Min.Price  num_pipeline__Max.Price  num_pipeline__MPG.city  \
# 0                 -0.485787                -0.282465                0.471312
# 1                  1.388017                 1.531409               -0.781032
# 2                  1.008658                 0.948052               -0.423219
# 3                  1.571949                 2.069191               -0.602126
# 4                  0.755752                 1.303535               -0.065407
# ..                      ...                      ...                     ...
# 88                -0.060445                 0.073018               -0.959938
# 89                 0.054512                 0.045673               -0.244313
# 90                 0.663786                 0.164167               -0.781032
# 91                 0.537333                 0.145937               -0.244313
# 92                 0.882205                 0.601684               -0.423219
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test  , y_train , y_test = train_test_split(x1  , y , test_size  = 0.15 , random_state = 12)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (79, 26)
# (14, 26)
# (79,)
# (14,)

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
R   = Ridge(alpha=75.0 , max_iter= 5)

# %%
# Model fitting

# %%
R.fit(x_train  , y_train )
# Out:
# Ridge(alpha=75.0, max_iter=5)

# %% [markdown]
# ### Training Evaluation

# %%
y_train_pred = R.predict(x_train)

# %%
from sklearn.metrics import mean_absolute_error ,mean_squared_error,\
mean_absolute_percentage_error ,r2_score  , root_mean_squared_error

# %%
MSE  =  mean_squared_error(y_train  , y_train_pred)
RMSE  =root_mean_squared_error(y_train  , y_train_pred)
MAE = mean_absolute_error(y_train  , y_train_pred)
MAPE  =  mean_absolute_percentage_error(y_train  , y_train_pred)
r2 = r2_score(y_train  , y_train_pred)

print(f'MSE --> {MSE} ')
print(f'RMSE --> {RMSE} ')
print(f'MAE --> {MAE} ')
print(f'MAPE --> {MAPE} ')
print(f'R2 --> {r2} ')
# Out:
# MSE --> 8.613073124080358
# RMSE --> 2.9348037624482424
# MAE --> 1.9934184594374742
# MAPE --> 0.10508053849734725
# R2 --> 0.9134843106772617

# %%
# Test Evaluation
y_test_pred = R.predict(x_test)
MSE  =  mean_squared_error(y_test  , y_test_pred)
RMSE  =root_mean_squared_error(y_test  , y_test_pred)
MAE = mean_absolute_error(y_test  , y_test_pred)
MAPE  =  mean_absolute_percentage_error(y_test  , y_test_pred)
r2 = r2_score(y_test  , y_test_pred)

print(f'MSE --> {MSE} ')
print(f'RMSE --> {RMSE} ')
print(f'MAE --> {MAE} ')
print(f'MAPE --> {MAPE} ')
print(f'R2 --> {r2} ')
# Out:
# MSE --> 8.987636205884405
# RMSE --> 2.9979386594599307
# MAE --> 2.3301015378795435
# MAPE --> 0.12712446549076317
# R2 --> 0.8228697079309143

# %%
from sklearn.linear_model import Lasso

# %%
model = Lasso(alpha = 3.5)
model.fit(x_train , y_train)
# Out:
# Lasso(alpha=3.5)

# %%
# Traning evaluation
L_y_train_pred =model.predict(x_train)

# %%
MSE  =  mean_squared_error(y_train  , L_y_train_pred)
RMSE  =root_mean_squared_error(y_train  , L_y_train_pred)
MAE = mean_absolute_error(y_train  , L_y_train_pred)
MAPE  =  mean_absolute_percentage_error(y_train  , L_y_train_pred)
r2 = r2_score(y_train  , L_y_train_pred)

print(f'MSE --> {MSE} ')
print(f'RMSE --> {RMSE} ')
print(f'MAE --> {MAE} ')
print(f'MAPE --> {MAPE} ')
print(f'R2 --> {r2} ')
# Out:
# MSE --> 12.399861017221312
# RMSE --> 3.5213436380480267
# MAE --> 2.703559718137559
# MAPE --> 0.16264645037036143
# R2 --> 0.8754471826772519

# %%
# Traning evaluation
L_y_test_pred =model.predict(x_test)

# %%
MSE  =  mean_squared_error(y_test  , L_y_test_pred)
RMSE  =root_mean_squared_error(y_test  , L_y_test_pred)
MAE  = mean_absolute_error(y_test  , L_y_test_pred)
MAPE  =  mean_absolute_percentage_error(y_test  , L_y_test_pred)
r2 = r2_score(y_test  , L_y_test_pred)

print(f'MSE --> {MSE} ')
print(f'RMSE --> {RMSE} ')
print(f'MAE --> {MAE} ')
print(f'MAPE --> {MAPE} ')
print(f'R2 --> {r2} ')
# Out:
# MSE --> 7.112591125392688
# RMSE --> 2.6669441549070143
# MAE --> 2.2764321830643808
# MAPE --> 0.1355037659332303
# R2 --> 0.8598235048071996

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
model  =  Ridge(alpha  =  2.5)
cv  =  cross_val_score(model ,x_train , y_train , cv  =  5)

# %%
cv.mean()
# Out:
# np.float64(0.9957339832370163)

# %%
cv.std()
# Out:
# np.float64(0.004198740862980703)

# %%
model.alpha
# Out:
# 2.5

# %%
model1  =  Ridge(alpha  =  4.5)
cv1  =  cross_val_score(model1 ,x_train , y_train , cv  =  5)

# %%
cv1.mean()
# Out:
# np.float64(0.9909257089228453)

# %%
cv1.std()
# Out:
# np.float64(0.008944675096089615)

# %%
from sklearn.linear_model import RidgeCV
model  =  RidgeCV(alphas=[2,4,6, 1]).fit(x_train, y_train)

# %%
model.alphas
# Out:
# [2, 4, 6, 1]

# %%
model.score(x_train , y_train)
# Out:
# 0.9998024995945392

# %%
model.score(x_test , y_test)
# Out:
# 0.9993395648975263

# %%
print(RidgeCV.__doc__)
# Out:
# Ridge regression with built-in cross-validation.
#
# See glossary entry for :term:`cross-validation estimator`.
#
# By default, it performs efficient Leave-One-Out Cross-Validation.
#
# Read more in the :ref:`User Guide <ridge_regression>`.
#
# Parameters
# ----------
# alphas : array-like of shape (n_alphas,), default=(0.1, 1.0, 10.0)
#     Array of alpha values to try.
#     Regularization strength; must be a positive float. Regularization
#     improves the conditioning of the problem and reduces the variance of
#     the estimates. Larger values specify stronger regularization.
#     Alpha corresponds to ``1 / (2C)`` in other linear models such as
#     :class:`~sklearn.linear_model.LogisticRegression` or
#     :class:`~sklearn.svm.LinearSVC`.
#     If using Leave-One-Out cross-validation, alphas must be strictly positive.
#
# fit_intercept : bool, default=True
#     Whether to calculate the intercept for this model. If set
# ...
